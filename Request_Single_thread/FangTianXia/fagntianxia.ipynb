# %%
import requests

# 'https://newhouse.fang.com/house/s/b91/?ctm=1.bj.xf_search.page.2'
# 'https://newhouse.fang.com/house/s/b92/?ctm=1.bj.xf_search.page.2'
# 'https://newhouse.fang.com/house/s/b93/?ctm=1.bj.xf_search.page.4'
# 'https://newhouse.fang.com/house/s/b94/?ctm=1.bj.xf_search.page.5'
url = 'https://newhouse.fang.com/house/s/b91/?ctm=1.bj.xf_search.page.2'

# %%
response = requests.get(url)
response.content.decode('gbk')
# Out:
# '<!doctype html>\n<html>\n<head>\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta name="renderer" content="webkit">\n<meta charset="gb2312">\n<meta name="keywords" content="2020北京楼盘信息,2020北京新楼盘信息">\n<meta name="description" content="北京新房，现有新楼盘741个，房天下北京新房网为您提供大量优质真实的北京新房出售信息及最新新楼盘房价信息，为您创造最佳新房购房体验。">\n<meta name="author" content="SFun ZBS Team">\n<meta name="location" content="city=北京;coord=39.9081726,116.3979471;" />\n<meta name="mobile-agent" content="format=html5;url=https://m.fang.com/xf/bj/" />\n<link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.fang.com/xf/bj/" >\t\t\n<meta http-equiv="Content-Language" content="zh-cn">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta property="og:type" content="image"/>\n<meta property="og:image" content="//static.soufunimg.com/home/online/common/fanglogo.jpg"/>\n<title>北京楼盘-北京新楼盘-北京新房-北京房天下</title>\n<script type="text/javascript" src="//static.soufunimg.com/newhouse/
# ...
